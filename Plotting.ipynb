# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import os

# %%
PATH = 'experiments'
DATASET = '100k_sample1'
ALGS = ['pop', 'itemknn', 'bpr', 'neumf', 'multivae', 'lightgcn']
CHOICE_MODELS = ['rank_based', 'us_centric']

# %%
df = pd.read_csv(PATH+'/'+DATASET+'_'+'itemknn_'+'rank_based/'+'user_based_metrics.csv')
df
# Out:
#            model choice_model  iteration country  user_count       jsd  \
# 0        ItemKNN   rank_based          1      RU           1  0.686918
# 1        ItemKNN   rank_based          1      IT           1  0.695781
# 2        ItemKNN   rank_based          1      BR           1  0.495415
# 3        ItemKNN   rank_based          1      RU           1  0.511749
# 4        ItemKNN   rank_based          1      UK           1  0.488033
# ...          ...          ...        ...     ...         ...       ...
# 1177595  ItemKNN   rank_based        100      RU           1  0.590295
# 1177596  ItemKNN   rank_based        100      RU           1  0.439977
# 1177597  ItemKNN   rank_based        100      PL           1  0.486980
# 1177598  ItemKNN   rank_based        100      DE           1  0.467624
# 1177599  ItemKNN   rank_based        100      UA           1  0.495478
#
#           bin_jsd  us_proportion  local_proportion  interaction_us_proportion  \
# ...

# %%
sns.regplot(data=df, x="iteration", y="local_proportion", x_estimator=np.mean, order=4, line_kws = {'color':'red'}, scatter_kws = {'alpha': 0.1})
# Out:
# <AxesSubplot:xlabel='iteration', ylabel='local_proportion'>

# %%
df = pd.read_csv(PATH+'/'+DATASET+'_'+'multivae_'+'rank_based/'+'user_based_metrics.csv')
sns.regplot(data=df, x="iteration", y="local_proportion", x_estimator=np.mean, order=4, line_kws = {'color':'red'}, scatter_kws = {'alpha': 0.1})
# Out:
# <AxesSubplot:xlabel='iteration', ylabel='local_proportion'>

# %%
df = pd.read_csv(PATH+'/'+DATASET+'_'+'bpr_'+'rank_based/'+'user_based_metrics.csv')
sns.regplot(data=df, x="iteration", y="local_proportion", x_estimator=np.mean, order=4, line_kws = {'color':'red'}, scatter_kws = {'alpha': 0.1})
# Out:
# <AxesSubplot:xlabel='iteration', ylabel='local_proportion'>

# %%
df = pd.read_csv(PATH+'/'+DATASET+'_'+'neumf_'+'rank_based/'+'user_based_metrics.csv')
sns.regplot(data=df, x="iteration", y="local_proportion", x_estimator=np.mean, order=4, line_kws = {'color':'red'}, scatter_kws = {'alpha': 0.1})
# Out:
# <AxesSubplot:xlabel='iteration', ylabel='local_proportion'>

# %%
df = pd.read_csv(PATH+'/'+DATASET+'_'+'pop_'+'rank_based/'+'user_based_metrics.csv')
sns.regplot(data=df, x="iteration", y="local_proportion", x_estimator=np.mean, order=4, line_kws = {'color':'red'}, scatter_kws = {'alpha': 0.1})
# Out:
# <AxesSubplot:xlabel='iteration', ylabel='local_proportion'>

# %% [markdown]
# ## BPR

# %%
g = sns.FacetGrid(df[df.country.isin(['DE', 'UK', 'BR', 'FI', 'JP'])], col="country", margin_titles=True)
g.map(sns.regplot, "iteration", "local_proportion", x_estimator=np.mean, order=2, line_kws = {'color':'red'}, scatter_kws = {'alpha': 0.1})

# %%
df = pd.read_csv(PATH+'/'+DATASET+'_'+'bpr_'+'us_centric/'+'user_based_metrics.csv')
g = sns.FacetGrid(df[df.country.isin(['DE', 'UK', 'BR', 'FI', 'JP'])], col="country", margin_titles=True)
g.map(sns.regplot, "iteration", "local_proportion", x_estimator=np.mean, order=2, line_kws = {'color':'red'}, scatter_kws = {'alpha': 0.1})

# %% [markdown]
# ## NeuMF

# %%
df = pd.read_csv(PATH+'/'+DATASET+'_'+'neumf_'+'rank_based/'+'user_based_metrics.csv')
g = sns.FacetGrid(df[df.country.isin(['DE', 'UK', 'BR', 'FI', 'JP'])], col="country", margin_titles=True)
g.map(sns.regplot, "iteration", "local_proportion", x_estimator=np.mean, order=4, line_kws = {'color':'red'}, scatter_kws = {'alpha': 0.1})

# %%
df = pd.read_csv(PATH+'/'+DATASET+'_'+'neumf_'+'us_centric/'+'user_based_metrics.csv')
g = sns.FacetGrid(df[df.country.isin(['DE', 'UK', 'BR', 'FI', 'JP'])], col="country", margin_titles=True)
g.map(sns.regplot, "iteration", "local_proportion", x_estimator=np.mean, order=4, line_kws = {'color':'red'}, scatter_kws = {'alpha': 0.1})

# %% [markdown]
# ## MultiVAE

# %%
df = pd.read_csv(PATH+'/'+DATASET+'_'+'multivae_'+'rank_based/'+'user_based_metrics.csv')
g = sns.FacetGrid(df[df.country.isin(['DE', 'UK', 'BR', 'FI', 'JP'])], col="country", margin_titles=True)
g.map(sns.regplot, "iteration", "local_proportion", x_estimator=np.mean, order=4, line_kws = {'color':'red'}, scatter_kws = {'alpha': 0.1})

# %%
df = pd.read_csv(PATH+'/'+DATASET+'_'+'multivae_'+'us_centric/'+'user_based_metrics.csv')
g = sns.FacetGrid(df[df.country.isin(['DE', 'UK', 'BR', 'FI', 'JP'])], col="country", margin_titles=True)
g.map(sns.regplot, "iteration", "local_proportion", x_estimator=np.mean, order=4, line_kws = {'color':'red'}, scatter_kws = {'alpha': 0.1})

# %% [markdown]
# ## ItemKNN

# %%
df = pd.read_csv(PATH+'/'+DATASET+'_'+'itemknn_'+'rank_based/'+'user_based_metrics.csv')
g = sns.FacetGrid(df[df.country.isin(['DE', 'UK', 'BR', 'FI', 'JP'])], col="country", margin_titles=True)
g.map(sns.regplot, "iteration", "local_proportion", x_estimator=np.mean, order=4, line_kws = {'color':'red'}, scatter_kws = {'alpha': 0.1})

# %%
df = pd.read_csv(PATH+'/'+DATASET+'_'+'itemknn_'+'us_centric/'+'user_based_metrics.csv')
g = sns.FacetGrid(df[df.country.isin(['DE', 'UK', 'BR', 'FI', 'JP'])], col="country", margin_titles=True)
g.map(sns.regplot, "iteration", "local_proportion", x_estimator=np.mean, order=4, line_kws = {'color':'red'}, scatter_kws = {'alpha': 0.1})

# %% [markdown]
# ## POP

# %%
df = pd.read_csv(PATH+'/'+DATASET+'_'+'pop_'+'rank_based/'+'user_based_metrics.csv')
g = sns.FacetGrid(df[df.country.isin(['DE', 'UK', 'BR', 'FI', 'JP'])], col="country", margin_titles=True)
g.map(sns.regplot, "iteration", "local_proportion", x_estimator=np.mean, order=4, line_kws = {'color':'red'}, scatter_kws = {'alpha': 0.1})

# %%
df = pd.read_csv(PATH+'/'+DATASET+'_'+'pop_'+'us_centric/'+'user_based_metrics.csv')
g = sns.FacetGrid(df[df.country.isin(['DE', 'UK', 'BR', 'FI', 'JP'])], col="country", margin_titles=True)
g.map(sns.regplot, "iteration", "local_proportion", x_estimator=np.mean, order=4, line_kws = {'color':'red'}, scatter_kws = {'alpha': 0.1})

# %% [markdown]
# ## TABLE of SIGNIFICANCE
# Country vs ALG (+ choice model)
# yes/no - significant change between iterations 0 and 100
